# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"Movie-Rating.csv")
df
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
len(df)
# Out:
# 559

# %%
np.__version__
# Out:
# '1.26.4'

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
df.shape
# Out:
# (559, 6)

# %%
df.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
df.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
df.columns = ["Film","Genre","CriticRatings","AudienceRatings","BudgetMillions","ReleaseYear"]

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'CriticRatings', 'AudienceRatings', 'BudgetMillions',
#        'ReleaseYear'],
#       dtype='object')

# %%
df.head(2)
# Out:
#                     Film      Genre  CriticRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
#
#    BudgetMillions  ReleaseYear
# 0               8         2009
# 1             105         2008

# %%
df.Film = df.Film.astype('category')
df.Genre = df.Genre.astype('category')
df.ReleaseYear = df.ReleaseYear.astype('category')

# %%
df.describe()
# Out:
#        CriticRatings  AudienceRatings  BudgetMillions
# count     559.000000       559.000000      559.000000
# mean       47.309481        58.744186       50.236136
# std        26.413091        16.826887       48.731817
# min         0.000000         0.000000        0.000000
# 25%        25.000000        47.000000       20.000000
# 50%        46.000000        58.000000       35.000000
# 75%        70.000000        72.000000       65.000000
# max        97.000000        96.000000      300.000000

# %%
df.describe(include = "all")
# Out:
#                          Film   Genre  CriticRatings  AudienceRatings  \
# count                     559     559     559.000000       559.000000
# unique                    559       7            NaN              NaN
# top     (500) Days of Summer   Comedy            NaN              NaN
# freq                        1     172            NaN              NaN
# mean                      NaN     NaN      47.309481        58.744186
# std                       NaN     NaN      26.413091        16.826887
# min                       NaN     NaN       0.000000         0.000000
# 25%                       NaN     NaN      25.000000        47.000000
# 50%                       NaN     NaN      46.000000        58.000000
# 75%                       NaN     NaN      70.000000        72.000000
# max                       NaN     NaN      97.000000        96.000000
#
#         BudgetMillions  ReleaseYear
# count       559.000000        559.0
# unique             NaN          5.0
# ...

# %%
neumeric_df = df.select_dtypes(include = ["number"])
neumeric_df
# Out:
#      CriticRatings  AudienceRatings  BudgetMillions
# 0               87               81               8
# 1                9               44             105
# 2               30               52              20
# 3               93               84              18
# 4               55               70              20
# ..             ...              ...             ...
# 554             26               36              50
# 555             68               52              18
# 556             89               73              65
# 557             90               87              24
# 558             14               42              80
#
# [559 rows x 3 columns]

# %%
neumeric_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CriticRatings    559 non-null    int64
#  1   AudienceRatings  559 non-null    int64
#  2   BudgetMillions   559 non-null    int64
# dtypes: int64(3)
# memory usage: 13.2 KB

# %%
category_df = df.select_dtypes(include = ["category"])
category_df
# Out:
#                       Film      Genre ReleaseYear
# 0    (500) Days of Summer      Comedy        2009
# 1              10,000 B.C.  Adventure        2008
# 2               12 Rounds      Action        2009
# 3                127 Hours  Adventure        2010
# 4                17 Again      Comedy        2009
# ..                     ...        ...         ...
# 554          Your Highness     Comedy        2011
# 555        Youth in Revolt     Comedy        2009
# 556                 Zodiac   Thriller        2007
# 557            Zombieland      Action        2009
# 558              Zookeeper     Comedy        2011
#
# [559 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   ReleaseYear      559 non-null    int64
# dtypes: category(2), int64(4)
# memory usage: 40.1 KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
# joint plot
j1 = sns.jointplot(data = df,x='CriticRatings',y='AudienceRatings')

# %%
# joint plot
j11 = sns.jointplot(data = df,x='CriticRatings',y='AudienceRatings',kind='kde') # kind by defalut scater plot

# %%
# joint plot
j11 = sns.jointplot(data = df,x='CriticRatings',y='AudienceRatings',kind='hex') # kind by defalut scater plot #"scatter" | "kde" | "hist" | "hex" | "reg" | "resid"

# %%
# joint plot
j2 = sns.jointplot(data = df,x='CriticRatings',y='AudienceRatings',hue='ReleaseYear')

# %%
# joint plot
j2 = sns.jointplot(data = df,x='CriticRatings',y='AudienceRatings',hue='ReleaseYear',kind='kde') #"scatter" | "kde" | "hist" | "hex" | "reg" | "resid"

# %%
# joint plot
j3 = sns.jointplot(data = df,x='CriticRatings',y='AudienceRatings',hue='Genre')

# %%
#histplot
h1 = sns.distplot(df.CriticRatings,bins=20)

# %%
#histplot
h2 = sns.distplot(df.AudienceRatings,bins=20)

# %%
#histplot
sns.set_style("darkgrid")   #{darkgrid, whitegrid, dark, white, ticks}
h3 = sns.distplot(df.BudgetMillions)

# %%
#histplot
sns.set_style("whitegrid")   #{darkgrid, whitegrid, dark, white, ticks}
h4 = sns.distplot(df.BudgetMillions)

# %%
#histplot
sns.set_style("white")   #{darkgrid, whitegrid, dark, white, ticks}
h5 = sns.distplot(df.BudgetMillions)

# %%
#lmplot
l1 = sns.lmplot(data =df,x="AudienceRatings",y="CriticRatings",fit_reg = True)

# %%
#lmplot
l11 = sns.lmplot(data =df,x="AudienceRatings",y="CriticRatings",fit_reg = True,hue="Genre")

# %%
#lmplot
l12 = sns.lmplot(data =df,x="AudienceRatings",y="CriticRatings",fit_reg = True,hue="ReleaseYear")

# %%
#lmplot
l2 = sns.lmplot(data =df,x="CriticRatings",y="AudienceRatings",fit_reg = True)

# %%
#lmplot
l21 = sns.lmplot(data =df,x="CriticRatings",y="AudienceRatings",fit_reg = True,hue="Genre")

# %%
#lmplot
l22 = sns.lmplot(data =df,x="CriticRatings",y="AudienceRatings",fit_reg = True,hue="ReleaseYear")

# %%
#boxplot

b1 = sns.boxplot(df.CriticRatings)

# %%
b11 = sns.boxplot(df.CriticRatings,orient= "y" ) # "v"| "h" | "x" | "y"

# %%
b2 = sns.boxplot(data=df,x="ReleaseYear",y="CriticRatings")

# %%
b21 = sns.boxplot(data=df,x="ReleaseYear",y="AudienceRatings")

# %%
b31 = sns.boxplot(data=df,x="Genre",y="CriticRatings")

# %%
b32 = sns.boxplot(data=df,x="Genre",y="AudienceRatings")

# %%
#violin plot
v1 = sns.violinplot(df.CriticRatings)

# %%
v21 = sns.violinplot(data=df,x="ReleaseYear",y="CriticRatings")

# %%
v22 = sns.violinplot(data=df,x="ReleaseYear",y="AudienceRatings")

# %%
v31 = sns.violinplot(data=df,x="Genre",y="CriticRatings")

# %%
v32 = sns.violinplot(data=df,x="Genre",y="AudienceRatings")

# %%
#facet grid
f1 = sns.FacetGrid(data=df,row="ReleaseYear",col="Genre")
f1 = f1.map(plt.scatter,'CriticRatings','AudienceRatings')

# %%
#facet grid
f12 = sns.FacetGrid(data=df,row="ReleaseYear",col="Genre",hue='Genre')
f12 = f12.map(plt.scatter,'CriticRatings','AudienceRatings')

# %%
#facet grid
f13 = sns.FacetGrid(data=df,row="ReleaseYear",col="Genre",hue='ReleaseYear')
f13 = f12.map(plt.scatter,'CriticRatings','AudienceRatings')

# %%
#facet grid
f2 = sns.FacetGrid(data=df,row="Genre",col="ReleaseYear")
f2=f2.map(plt.scatter,'CriticRatings','AudienceRatings')

# %%
f21 = sns.FacetGrid(data=df,row="Genre",col="ReleaseYear",hue='ReleaseYear')
f21=f21.map(plt.scatter,'CriticRatings','AudienceRatings')

# %%
f22 = sns.FacetGrid(data=df,row="Genre",col="ReleaseYear",hue='ReleaseYear')
f22=f22.map(plt.bar,'CriticRatings','AudienceRatings')

# %%
f23 = sns.FacetGrid(data=df,row="Genre",col="ReleaseYear",hue='ReleaseYear')
f23=f23.map(plt.hist,"BudgetMillions")

# %%
#heat map
plt.figure(figsize=(5,5))
sns.heatmap(neumeric_df.corr(), square=True,annot=True,fmt='0.2f',linecolor='white')
plt.show()
